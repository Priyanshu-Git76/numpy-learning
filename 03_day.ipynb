# %% [markdown]
# ### Advance opertaion with Bussiness example

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])
print("==== Zomato sales analysis ====")
print("\n Sales data shape ",sales_data.shape)
print("\n sample data ffor 1st 3 resturant",sales_data[:3])
# Out:
# ==== Zomato sales analysis ====
#
#  Sales data shape  (5, 5)
#
#  sample data ffor 1st 3 resturant [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %% [markdown]
# ### Total sale per year

# %%
print(np.sum(sales_data,axis=0))
yearly_total = np.sum(sales_data[:,1:],axis=0)
print("yearly total ",yearly_total)
# Out:
# [     15  810000  945000 1085000 1240000]
# yearly total  [ 810000  945000 1085000 1240000]

# %%
years = [2021, 2022, 2023, 2024]

for year, total in zip(years, yearly_total):
    print(year, "Total Sales:", total)
# Out:
# 2021 Total Sales: 810000
# 2022 Total Sales: 945000
# 2023 Total Sales: 1085000
# 2024 Total Sales: 1240000

# %% [markdown]
# ### Minimum sales per restaurant

# %%
min_sales = np.min(sales_data[:,1:],axis = 1)
print("minimum sales",min_sales)
# Out:
# minimum sales [150000 120000 200000 180000 160000]

# %% [markdown]
# ### Maximum sale per year

# %%
max_sales = np.max(sales_data[:,1],axis = 0)
print(max_sales)
# Out:
# 200000

# %% [markdown]
# Average sales per restaurant

# %%
avg_sales = np.mean(sales_data[:,1:],axis = 1)
print(avg_sales)
# Out:
# [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:,1:],axis =1)
print(cumsum)
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
plt.Figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales accoross all restaurant")
plt.xlabel("years")
plt.ylabel("sales")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("vector addition:", vector1+vector2)

print("\n Multiplication vector", vector1*vector2)

print("\nDot Product", np.dot(vector1, vector2))

angle = np.arccos(np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print(angle)
# Out:
# vector addition: [ 7  9 11 13 15]
#
#  Multiplication vector [ 6 14 24 36 50]
#
# Dot Product 130
# 0.26554161733900966

# %% [markdown]
# ### vectorized opertion

# %%
restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized Upper", vectorized_upper(restaurant_types))
# Out:
# Vectorized Upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %% [markdown]
# ### Broadcast

# %%
monthly_avg = sales_data[:, 1:] / 12

print(monthly_avg)
